# %%
from matplotlib import pyplot as plt

# %% [markdown]
# Raw data is taken from a screenshot of a chess.com starting game.  I first split the screen in half with spectacle.  It splits the screen exactly in half.

# %%
data = plt.imread("../data/raw/board.png")
data
# Out:
# array([[[0.79607844, 0.79607844, 0.79607844, 1.        ],
#         [0.79607844, 0.79607844, 0.79607844, 1.        ],
#         [0.79607844, 0.79607844, 0.79607844, 1.        ],
#         ...,
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ],
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ],
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ]],
#
#        [[0.79607844, 0.79607844, 0.79607844, 1.        ],
#         [0.79607844, 0.79607844, 0.79607844, 1.        ],
#         [0.79607844, 0.79607844, 0.79607844, 1.        ],
#         ...,
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ],
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ],
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ]],
#
#        [[0.79607844, 0.79607844, 0.79607844, 1.        ],
#         [0.79607844, 0.79607844, 0.79607844, 1.        ],
#         [0.79607844, 0.79607844, 0.79607844, 1.        ],
#         ...,
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ],
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ],
#         [0.9647059 , 0.9607843 , 0.95686275, 1.        ]],
#
#        ...,
#
#        [[0.49019608, 0.4862745 , 0.4745098 , 1.        ],
#         [0.4745098 , 0.47843137, 0.46666667, 1.        ],
#         [0.45490196, 0.45490196, 0.44705883, 1.        ],
#         ...,
#         [0.2627451 , 0.31764707, 0.33333334, 1.        ],
#         [0.25882354, 0.31764707, 0.32941177, 1.        ],
#         [0.2627451 , 0.32156864, 0.33333334, 1.        ]],
#
#        [[0.5019608 , 0.5019608 , 0.49411765, 1.        ],
#         [0.5019608 , 0.5019608 , 0.49411765, 1.        ],
#         [0.49019608, 0.49019608, 0.48235294, 1.        ],
#         ...,
#         [0.25882354, 0.3137255 , 0.3254902 , 1.        ],
#         [0.25882354, 0.31764707, 0.32941177, 1.        ],
#         [0.25882354, 0.3254902 , 0.33333334, 1.        ]],
#
#        [[0.5137255 , 0.5137255 , 0.5058824 , 1.        ],
#         [0.5176471 , 0.5176471 , 0.50980395, 1.        ],
#         [0.5137255 , 0.5176471 , 0.49803922, 1.        ],
#         ...,
#         [0.25490198, 0.32156864, 0.32941177, 1.        ],
#         [0.25490198, 0.32156864, 0.32941177, 1.        ],
#         [0.25490198, 0.32156864, 0.3254902 , 1.        ]]], dtype=float32)

# %%
plt.imshow(data)

# %%
data.shape
# Out:
# (1800, 2880, 4)

# %% [markdown]
# I make the interim data by taking a screenshot of each space of the board.

# %%
i = 0
j = 0
for i in range(8):
    for j in range(8):
        x = 477 + 146*i
        y = 193 + 146*j
        plt.imshow(data[x:x+146,y:y+146,:])
        plt.savefig('../data/interim/{}_{}.png'.format(i,j))

# %% [markdown]
# I make the processed data by putting them into 3 processed folders: black pawn, other, and white pawn
